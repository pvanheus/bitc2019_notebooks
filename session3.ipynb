# %%
import time

# %%
print(time.ctime())
# Out:
# Wed Feb 20 14:13:01 2019

# %%
print(time.ctime)
# Out:
# <built-in function ctime>

# %%
print()

# %%
import numpy

# %%
numpy.max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-b5aa5e1956d1> in <module>
# ----> 1 numpy.max()
#
# TypeError: amax() missing 1 required positional argument: 'a'

# %%
data = numpy.loadtxt(fname='data/inflammation-01.csv', delimiter=',')

# %%
patient_0 = data[0, :]
print('maximum inflammation for patient 0:', numpy.max(patient_0))
# Out:
# maximum inflammation for patient 0: 18.0

# %%
patient_2 = data[1, :]

# %%
numpy.max(patient_2)
# Out:
# 18.0

# %%
dataslice = data[:4, :10]

# %%
numpy.max(dataslice)
# Out:
# 9.0

# %%
numpy.max(dataslice, axis=1)
# Out:
# array([8., 6., 9., 7.])

# %%
numpy.max(dataslice, axis=0)
# Out:
# array([0., 1., 2., 3., 4., 2., 6., 7., 8., 9.])

# %%
print(dataslice.shape)
# Out:
# (4, 10)

# %%
max_by_column = numpy.max(dataslice, axis=0)
print(max_by_column.shape)
# Out:
# (10,)

# %%
import matplotlib.pyplot

# %%
# %matplotlib inline

# %%
image = matplotlib.pyplot.imshow(data)
matplotlib.pyplot.show()

# %%
avg_inflammation = numpy.mean(data, axis=0)
avg_plot = matplotlib.pyplot.plot(avg_inflammation)
matplotlib.pyplot.show()

# %%
avg_inflammation = numpy.mean(data, axis=0)
avg_plot = matplotlib.pyplot.plot(avg_inflammation)
matplotlib.pyplot.show()
print('hello')
# Out:
# hello

# %%
import matplotlib.pyplot as plt

# %%
max_inflammation = numpy.max(data, axis=0)
max_plot = plt.plot(max_inflammation)
plt.show()

# %%
min_inflammation = numpy.min(data, axis=0)
min_plot = plt.plot(min_inflammation)
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 3.0))
axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(data, axis=0))

axes2.set_ylabel('max')
axes2.plot(numpy.max(data, axis=0))

axes3.set_ylabel('min')
axes3.plot(numpy.min(data, axis=0))

fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(3.0, 10.0))
axes1 = fig.add_subplot(3, 1, 1)
axes2 = fig.add_subplot(3, 1, 2)
axes3 = fig.add_subplot(3, 1, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(data, axis=0))

axes2.set_ylabel('max')
axes2.plot(numpy.max(data, axis=0))

axes3.set_ylabel('min')
axes3.plot(numpy.min(data, axis=0))

fig.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize=(10.0, 3.0))
axes1 = fig.add_subplot(1, 3, 1)
axes2 = fig.add_subplot(1, 3, 2)
axes3 = fig.add_subplot(1, 3, 3)

axes1.set_ylabel('average')
axes1.plot(numpy.mean(data, axis=0))

axes2.set_ylabel('max')
axes2.plot(numpy.max(data, axis=0))

axes3.set_ylabel('min')
axes3.plot(numpy.min(data, axis=0))

plt.show()

# %%
mass = 47.5
age = 122
mass = mass * 2.0
age = age - 20
print(mass, age)
# Out:
# 95.0 102

# %%
first, second = 'Grace', 'Hopper'
third, fourth = second, first
print(third, fourth)
# Out:
# Hopper Grace

# %%
element = 'oxygen'
print('first three characters:', element[0:3])
print('last three characters:', element[3:6])
# Out:
# first three characters: oxy
# last three characters: gen

# %%
print(element[:4])
# Out:
# oxyg

# %%
print(element[4:])
# Out:
# en

# %%
print(element[:])
# Out:
# oxygen

# %%
print(element[-1])
# Out:
# n

# %%
element = 'oxygen'
print(element[1:-1])
# Out:
# xyge

# %%
print(element[3:3])

# %%
print(data[3:3, 4:4])
# Out:
# []

# %%
print(data[3:3, :])
# Out:
# []

# %%
print(element[4:3])
